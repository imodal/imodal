# %%
import sys
sys.path.append("../")

import torch
import matplotlib.pyplot as plt
import imodal
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
imodal.Utilities.set_compute_backend('keops')
dtype = torch.float32
# Out:
# [KeOps] Warning : Cuda libraries were not detected on the system or could not be loaded ; using cpu only mode

# %%
report = torch.load('/home/gris/Results/ExamplesIM/Imp1/exp_relancees/uniform_sig4_arap1.0e+00_cost1.0e-04_imp11.0e+01_18_07_2025__11_44_08/report.pth')
report
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 report = torch.load('/home/gris/Results/ExamplesIM/Imp1/exp_relancees/uniform_sig4_arap1.0e+00_cost1.0e-04_imp11.0e+01_18_07_2025__11_44_08/report.pth')
#       2 report
#
# File ~/miniconda3/envs/envimodal/lib/python3.11/site-packages/torch/serialization.py:809, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     807             except RuntimeError as e:
#     808                 raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# --> 809         return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#     810 if weights_only:
#     811     try:
#
# File ~/miniconda3/envs/envimodal/lib/python3.11/site-packages/torch/serialization.py:1172, in _load(zip_file, map_location, pickle_module, pickle_file, **pickle_load_args)
# ...

# %%
path = '/home/gris/Results/ExamplesIM/Imp1/exp_relancees/uniform_sig4_arap1.0e+00_cost1.0e-04_imp11.0e+01_18_07_2025__11_44_08/'

# %%
path = '/home/gris/Results/ExamplesIM/ARAPImp1/ExpRelancees/lincomb_17_07_2025__16_10_12/'

# %%
report = torch.load(path + 'report.pth', map_location='cpu')

# %%
report
# Out:
# {'timestamp': '18_07_2025__11_44_08',
#  'method': 'moments',
#  'backend': 'torch',
#  'device': 'cuda:1',
#  'seed': 0,
#  'sigma_fac': 4.0,
#  'nu_fac': 1e-05,
#  'lam': 10000000.0,
#  'imp1_coeff': 10.0,
#  'gt_coeff': 100.0,
#  'maxiter': 50,
#  'solver': 'midpoint',
#  'solver_it': 8,
#  'stop_after_fit': False,
#  'opt_time': 84.20691682607867,
#  'n_iter': 5,
#  'costs': {'deformation': [0.0,
#    874.5821304146174,
#    2039.6452469949706,
#    2653.37532889214,
#    2653.37532889214],
#   'attach': [39696154.69747286,
#    6339360.754510593,
#    251477.53066112832,
#    156290.37603690277,
#    156290.37603690277]},
#  'varifold_facs': [1.0, 2.0, 4.0],
#  'case': 'uniform',
#  'imp1_sigma_fac': 4.0,
#  'learned_params': tensor([0.9224, 0.9678], dtype=torch.float64, requires_grad=True),
#  'learned_C': tensor([[[0.0454],
#           [0.0454],
#           [0.0454]],
#
#          [[0.0454],
#           [0.0454],
#           [0.0454]],
#
#          [[0.2760],
# ...

# %%
torch.load('../Results/Estimating_GMO_learned_params.pth')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 torch.load('../Results/Estimating_GMO_learned_params.pth')
#
# File ~/miniconda3/envs/envimodal/lib/python3.11/site-packages/torch/serialization.py:791, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     788 if 'encoding' not in pickle_load_args.keys():
#     789     pickle_load_args['encoding'] = 'utf-8'
# --> 791 with _open_file_like(f, 'rb') as opened_file:
#     792     if _is_zipfile(opened_file):
#     793         # The zipfile reader is going to advance the current file position.
#     794         # If we want to actually tail call to torch.jit.load, we need to
#     795         # reset back to the original position.
#     796         orig_position = opened_file.tell()
#
# ...
