# %%
# %load_ext autoreload
# %autoreload 2

import sys
import copy
import math
import pickle

sys.path.append("../../")

import numpy as np
import torch
import matplotlib.pyplot as plt

import implicitmodules.torch as dm

torch.set_default_tensor_type(torch.FloatTensor)

dm.Utilities.set_compute_backend('torch')
device = 'cpu'

# %%
source_image = dm.Utilities.load_greyscale_image("/home/leander/diffeo/implicitmodules/data/images/cross_+.png")
target_image = dm.Utilities.load_greyscale_image("/home/leander/diffeo/implicitmodules/data/images/cross_x.png")
# source_image = dm.Utilities.load_greyscale_image("/home/leander/diffeo/implicitmodules/data/images/heart_a.png")
# target_image = dm.Utilities.load_greyscale_image("/home/leander/diffeo/implicitmodules/data/images/heart_b.png")

# %%
# %matplotlib qt5
plt.subplot(1, 2, 1)
plt.imshow(source_image)

plt.subplot(1, 2, 2)
plt.imshow(target_image)

plt.show()

# %%
aabb = dm.Utilities.AABB(0., source_image.shape[0], 0., source_image.shape[1])

# Fill the unit square
points_density = 0.1
translation_pts = aabb.fill_uniform_density(points_density)
#sigma_translation = 3./points_count
# sigma_translation = 10./points_count
sigma_translation = 5.

translation = dm.DeformationModules.Translations(2, translation_pts.shape[0], sigma_translation, gd=translation_pts.to(device=device).requires_grad_())

rotation = dm.DeformationModules.LocalRotation(2, 20., gd=torch.tensor([[10., 10.]], requires_grad=False))
#rotation = dm.DeformationModules.LocalRotation(2, 25., gd=torch.tensor([[10., 10.]], requires_grad=True))

# %%
model = dm.Models.ModelImageRegistration(source_image, [rotation], dm.Attachment.EuclideanPointwiseDistanceAttachment(), fit_gd=[True], lam=100.)

# %%
shoot_method = 'euler'
shoot_it = 10

# %%
#fitter = dm.Models.ModelFittingGradientDescent(model, 1e-2, verbose=False)
fitter = dm.Models.ModelFittingScipy(model)
costs = fitter.fit([target_image], 100, options={'shoot_method': shoot_method, 'shoot_it': shoot_it})
# Out:
# Initial energy = 6577.890
# ================================================================================
# Time: 1.373555368045345
# Iteration: 1
# Total energy = 5263.73583984375
# Attach cost = 5149.90576171875
# Deformation cost = 113.83026123046875
# ================================================================================
# Time: 2.5698571710381657
# Iteration: 2
# Total energy = 5260.5615234375
# Attach cost = 5143.185546875
# Deformation cost = 117.37579345703125
# ================================================================================
# Time: 2.7716205990873277
# Iteration: 3
# Total energy = 5258.83984375
# Attach cost = 5141.94384765625
# Deformation cost = 116.8961181640625
# ================================================================================
# Time: 2.9763946610037237
# Iteration: 4
# Total energy = 5242.0634765625
# Attach cost = 5127.39892578125
# Deformation cost = 114.66456604003906
# ================================================================================
# Time: 3.5936331890989095
# Iteration: 5
# Total energy = 4865.02587890625
# Attach cost = 4761.685546875
# Deformation cost = 103.34033966064453
# ================================================================================
# Time: 3.795696455053985
# Iteration: 6
# Total energy = 4708.55322265625
# Attach cost = 4601.1259765625
# Deformation cost = 107.42744445800781
# ================================================================================
# Time: 4.200875126989558
# Iteration: 7
# Total energy = 4584.130859375
# Attach cost = 4459.07763671875
# Deformation cost = 125.0531234741211
# ================================================================================
# Time: 4.412149775074795
# Iteration: 8
# Total energy = 4092.03173828125
# Attach cost = 3917.097900390625
# Deformation cost = 174.93380737304688
# ================================================================================
# Time: 4.822870071046054
# Iteration: 9
# Total energy = 3928.095703125
# Attach cost = 3740.106689453125
# Deformation cost = 187.9890594482422
# ================================================================================
# Time: 5.014569733059034
# Iteration: 10
# Total energy = 3464.279296875
# Attach cost = 3204.789794921875
# Deformation cost = 259.4895324707031
# ================================================================================
# Time: 5.623655989067629
# Iteration: 11
# Total energy = 2009.151123046875
# Attach cost = 1696.2049560546875
# Deformation cost = 312.94622802734375
# ================================================================================
# Time: 6.014401965076104
# Iteration: 12
# Total energy = 1797.50830078125
# Attach cost = 1483.722900390625
# Deformation cost = 313.7853698730469
# ================================================================================
# Time: 6.413294730009511
# Iteration: 13
# Total energy = 1267.8251953125
# Attach cost = 975.9363403320312
# Deformation cost = 291.888916015625
# ================================================================================
# Time: 6.824347787071019
# Iteration: 14
# Total energy = 1192.096923828125
# Attach cost = 894.671142578125
# Deformation cost = 297.42584228515625
# ================================================================================
# Time: 7.220263651106507
# Iteration: 15
# Total energy = 1184.7548828125
# Attach cost = 884.0108032226562
# Deformation cost = 300.7440490722656
# ================================================================================
# Time: 7.618001837981865
# Iteration: 16
# Total energy = 1183.6488037109375
# Attach cost = 883.39013671875
# Deformation cost = 300.2586975097656
# ================================================================================
# Time: 7.8201333519537
# Iteration: 17
# Total energy = 1183.6085205078125
# Attach cost = 882.9839477539062
# Deformation cost = 300.6245422363281
# ================================================================================
# Time: 8.024811561917886
# Iteration: 18
# Total energy = 1183.6024169921875
# Attach cost = 883.0995483398438
# Deformation cost = 300.5028381347656
# ================================================================================
# Time: 8.229922018013895
# Iteration: 19
# Total energy = 1183.6011962890625
# Attach cost = 883.0896606445312
# Deformation cost = 300.5115051269531
# ================================================================================
# Time: 8.643510201945901
# Iteration: 20
# Total energy = 1183.5992431640625
# Attach cost = 883.0829467773438
# Deformation cost = 300.5163269042969
# ================================================================================
# Time: 8.846939692972228
# Iteration: 21
# Total energy = 1183.5919189453125
# Attach cost = 883.0772705078125
# Deformation cost = 300.5146179199219
# ================================================================================
# Time: 9.042491998989135
# Iteration: 22
# Total energy = 1183.559814453125
# Attach cost = 883.0744018554688
# Deformation cost = 300.48541259765625
# ================================================================================
# Time: 9.252840677043423
# Iteration: 23
# Total energy = 1183.4864501953125
# Attach cost = 883.0964965820312
# Deformation cost = 300.38995361328125
# ================================================================================
# Time: 9.652359175030142
# Iteration: 24
# Total energy = 1182.99560546875
# Attach cost = 884.2337646484375
# Deformation cost = 298.7618713378906
# ================================================================================
# Time: 9.857879454037175
# Iteration: 25
# Total energy = 1182.4334716796875
# Attach cost = 883.3763427734375
# Deformation cost = 299.0571594238281
# ================================================================================
# Time: 10.056984156137332
# Iteration: 26
# Total energy = 1181.14453125
# Attach cost = 882.5822143554688
# Deformation cost = 298.56231689453125
# ================================================================================
# Time: 10.250442451098934
# Iteration: 27
# Total energy = 1178.748046875
# Attach cost = 882.6915893554688
# Deformation cost = 296.056396484375
# ================================================================================
# Time: 10.462273672921583
# Iteration: 28
# Total energy = 1170.776123046875
# Attach cost = 885.308837890625
# Deformation cost = 285.46728515625
# ================================================================================
# Time: 10.656536281108856
# Iteration: 29
# Total energy = 1142.846435546875
# Attach cost = 902.6251831054688
# Deformation cost = 240.22122192382812
# ================================================================================
# Time: 11.055656197015196
# Iteration: 30
# Total energy = 1125.82177734375
# Attach cost = 914.3215942382812
# Deformation cost = 211.5001678466797
# ================================================================================
# Time: 11.461470544105396
# Iteration: 31
# Total energy = 1107.144775390625
# Attach cost = 919.4739990234375
# Deformation cost = 187.67074584960938
# ================================================================================
# Time: 11.654640445951372
# Iteration: 32
# Total energy = 1094.794921875
# Attach cost = 927.0225830078125
# Deformation cost = 167.77232360839844
# ================================================================================
# Time: 11.862852680962533
# Iteration: 33
# Total energy = 1069.56689453125
# Attach cost = 898.4032592773438
# Deformation cost = 171.1636962890625
# ================================================================================
# Time: 12.064617376076058
# Iteration: 34
# Total energy = 1066.447998046875
# Attach cost = 895.8967895507812
# Deformation cost = 170.55117797851562
# ================================================================================
# Time: 12.275659681065008
# Iteration: 35
# Total energy = 1062.8193359375
# Attach cost = 898.3232421875
# Deformation cost = 164.4960479736328
# ================================================================================
# Time: 12.474590101046488
# Iteration: 36
# Total energy = 1054.9022216796875
# Attach cost = 899.416259765625
# Deformation cost = 155.48593139648438
# ================================================================================
# Time: 12.6845326309558
# Iteration: 37
# Total energy = 1037.08154296875
# Attach cost = 898.6083984375
# Deformation cost = 138.47315979003906
# ================================================================================
# Time: 12.881721405079588
# Iteration: 38
# Total energy = 1026.55322265625
# Attach cost = 900.029296875
# Deformation cost = 126.52396392822266
# ================================================================================
# Time: 13.080531920073554
# Iteration: 39
# Total energy = 1022.1751098632812
# Attach cost = 909.4888916015625
# Deformation cost = 112.68622589111328
# ================================================================================
# Time: 13.27845680899918
# Iteration: 40
# Total energy = 1018.4186401367188
# Attach cost = 907.469970703125
# Deformation cost = 110.94866943359375
# ================================================================================
# Time: 13.484630312072113
# Iteration: 41
# Total energy = 1011.0225219726562
# Attach cost = 908.0103759765625
# Deformation cost = 103.01213073730469
# ================================================================================
# Time: 13.881726824911311
# Iteration: 42
# Total energy = 1010.0045166015625
# Attach cost = 910.9288940429688
# Deformation cost = 99.07565307617188
# ================================================================================
# Time: 14.084572795080021
# Iteration: 43
# Total energy = 1007.8017578125
# Attach cost = 912.4689331054688
# Deformation cost = 95.33280181884766
# ================================================================================
# Time: 14.492053655907512
# Iteration: 44
# Total energy = 1007.10791015625
# Attach cost = 914.8983764648438
# Deformation cost = 92.20954895019531
# ================================================================================
# Time: 14.689171015052125
# Iteration: 45
# Total energy = 1005.9403076171875
# Attach cost = 916.4203491210938
# Deformation cost = 89.51995086669922
# ================================================================================
# Time: 14.89835061901249
# Iteration: 46
# Total energy = 1005.0753173828125
# Attach cost = 918.573974609375
# Deformation cost = 86.50133514404297
# ================================================================================
# Time: 15.095744411926717
# Iteration: 47
# Total energy = 1004.5772705078125
# Attach cost = 919.705322265625
# Deformation cost = 84.87191772460938
# ================================================================================
# Time: 15.685436576139182
# Iteration: 48
# Total energy = 1004.0855102539062
# Attach cost = 921.1280517578125
# Deformation cost = 82.95746612548828
# ================================================================================
# Time: 16.0915559460409
# Iteration: 49
# Total energy = 1003.95849609375
# Attach cost = 921.189697265625
# Deformation cost = 82.76881408691406
# ================================================================================
# Time: 16.28351051104255
# Iteration: 50
# Total energy = 1003.91064453125
# Attach cost = 921.2008666992188
# Deformation cost = 82.70977020263672
# ================================================================================
# Time: 16.49031492206268
# Iteration: 51
# Total energy = 1003.9081420898438
# Attach cost = 921.23974609375
# Deformation cost = 82.66838073730469
# ================================================================================
# Time: 16.689772749086842
# Iteration: 52
# Total energy = 1003.9063720703125
# Attach cost = 921.3190307617188
# Deformation cost = 82.58733367919922
# ================================================================================
# Time: 21.025850468082353
# Iteration: 53
# Total energy = 1003.9044799804688
# Attach cost = 921.318603515625
# Deformation cost = 82.58586883544922
# ================================================================================
# Time: 26.890593788120896
# Iteration: 54
# Total energy = 1003.9044799804688
# Attach cost = 921.318603515625
# Deformation cost = 82.58586883544922
# ================================================================================
# Optimisation process exited with message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
# Final energy = 1003.9044799804688
# Closure evaluations = 135
# Time elapsed = 26.891401008935645

# %%
print("Optimised rotation center={center}".format(center=model.init_manifold[1].gd.detach().tolist()))
# Out:
# Optimised rotation center=[[15.49264144897461, 15.424398422241211]]

# %%
plt.plot(range(len(costs)), costs)
plt.show()

# %%
with torch.autograd.no_grad():
    deformed_image = model.compute_deformed(shoot_method, shoot_it)[0]

# %%
plt.subplot(1, 3, 1)
plt.imshow(source_image)

plt.subplot(1, 3, 2)
plt.imshow(deformed_image.numpy())

plt.subplot(1, 3, 3)
plt.imshow(target_image)
plt.show()
